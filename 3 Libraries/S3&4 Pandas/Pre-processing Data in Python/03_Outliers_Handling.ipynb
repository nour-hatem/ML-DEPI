# %% [markdown]
# # Outliers Handling
#
#
# <img src='https://cdn.analyticsvidhya.com/wp-content/uploads/2019/02/impact-of-outliers.png'>
#
# The outliers can be a result of a mistake during data collection or it can be just an indication of variance in your data.
#
# ### Important Note
# **Outliers not always a bad thing, handle outlier if you believe It's wrong or anomal data, if the outlier represents a usefull information of the variance of data so dont handle it.**
#
# Let’s have a look at some examples. Suppose you have been asked to observe the performance of Indian cricket team i.e Run made by each player and collect the data.
#
# <img src='https://miro.medium.com/max/304/1*MnIW35xSxsSiVopfbE6SxA.png'>
#
# As you can see from the above collected data that all other players scored 300+ except Player3 who scored 10. This figure can be just a typing mistake or it is showing the variance in your data and indicating that Player3 is performing very bad so, needs improvements.
#
#
# ### Table of Contents
# 1. Detect Outliers with Visualization.
# 2. Detect and Handle Outliers with Statistical methods.
#     - Outlier Handling via Removing
#     - Outlier Handling via Replacing with Median

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# ## 1) Detect Outliers with Visualization.

# %% [markdown]
# <img src='https://miro.medium.com/max/832/1*SNZCse_n6-hau15Gn01RLA.png'>

# %%
df = pd.read_csv('boston_house_prices.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
sns.boxplot(x='DIS', data=df)
sns.stripplot(x='DIS', data=df, color="#474646")
# Out:
# <Axes: xlabel='DIS'>

# %% [markdown]
# ## 2) Detect and Handle Outliers with Statistical methods.
# <img src='https://github.com/mnrclab/Preprocessing_ML_part1/raw/a30093a5fa52d89a8f8b876143fbce24c75dabdb/e_img.png'>

# %% [markdown]
# ### IQR (Interquartile Range)
#
# - IQR is a concept in statistics that is used to measure the statistical dispersion and data variability by dividing the dataset into quartiles.
# - Interquartile Range (IQR) is important because it is used to define the outliers.
#
# - It is the difference between the third quartile and the first quartile (IQR = Q3 -Q1).
#
# - Outliers in this case are defined as the observations that are below (Q1 − 1.5x IQR) or boxplot lower whisker or above (Q3 + 1.5x IQR) or boxplot upper whisker.
# <img src='https://miro.medium.com/max/2594/0*metZYDkpEy6nSlfc.png'>

# %% [markdown]
# **Steps**
# - For each column, first it computes the IQR = Q3 - Q1.
# - Then is discard values where less than (Q1 - IQR * 1.5) or more than (Q3 + IQR * 1.5)
# - Finally, result of this condition is used to index the dataframe.

# %% [markdown]
# ### 2.1) Outlier Handling via Removing

# %%
df = pd.read_csv('boston_house_prices.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
sns.boxplot(x='DIS', data=df)
sns.stripplot(x='DIS', data=df, color="#474646")
# Out:
# <Axes: xlabel='DIS'>

# %%
pip install datasist
# Out:
# Collecting datasist
#   Downloading datasist-1.5.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pandas in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (3.8.4)
# Requirement already satisfied: seaborn in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (0.13.2)
# Requirement already satisfied: numpy in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (1.26.4)
# Requirement already satisfied: jupyter in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (1.0.0)
# Requirement already satisfied: scikit-learn in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (1.4.2)
# Requirement already satisfied: nltk in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (3.8.1)
# Requirement already satisfied: Joblib in c:\users\baraa\anaconda3\lib\site-packages (from datasist) (1.4.2)
# Requirement already satisfied: notebook in c:\users\baraa\anaconda3\lib\site-packages (from jupyter->datasist) (7.0.8)
# Requirement already satisfied: qtconsole in c:\users\baraa\anaconda3\lib\site-packages (from jupyter->datasist) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\baraa\anaconda3\lib\site-packages (from jupyter->datasist) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\baraa\anaconda3\lib\site-packages (from jupyter->datasist) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\baraa\anaconda3\lib\site-packages (from jupyter->datasist) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\baraa\anaconda3\lib\site-packages (from jupyter->datasist) (7.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\baraa\anaconda3\lib\site-packages (from matplotlib->datasist) (2.9.0.post0)
# Requirement already satisfied: click in c:\users\baraa\anaconda3\lib\site-packages (from nltk->datasist) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\baraa\anaconda3\lib\site-packages (from nltk->datasist) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\baraa\anaconda3\lib\site-packages (from nltk->datasist) (4.66.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\baraa\anaconda3\lib\site-packages (from pandas->datasist) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\baraa\anaconda3\lib\site-packages (from pandas->datasist) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\baraa\anaconda3\lib\site-packages (from scikit-learn->datasist) (1.13.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\baraa\anaconda3\lib\site-packages (from scikit-learn->datasist) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\baraa\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->datasist) (1.16.0)
# Requirement already satisfied: colorama in c:\users\baraa\anaconda3\lib\site-packages (from click->nltk->datasist) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (1.6.0)
# Requirement already satisfied: psutil in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\baraa\anaconda3\lib\site-packages (from ipykernel->jupyter->datasist) (5.14.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\baraa\anaconda3\lib\site-packages (from ipywidgets->jupyter->datasist) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\baraa\anaconda3\lib\site-packages (from ipywidgets->jupyter->datasist) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\baraa\anaconda3\lib\site-packages (from ipywidgets->jupyter->datasist) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-console->jupyter->datasist) (3.0.43)
# Requirement already satisfied: pygments in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-console->jupyter->datasist) (2.15.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\baraa\anaconda3\lib\site-packages (from nbconvert->jupyter->datasist) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\baraa\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\baraa\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\baraa\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\baraa\anaconda3\lib\site-packages (from notebook->jupyter->datasist) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\baraa\anaconda3\lib\site-packages (from qtconsole->jupyter->datasist) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\baraa\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->datasist) (0.5.1)
# Requirement already satisfied: decorator in c:\users\baraa\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\baraa\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\baraa\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->datasist) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->datasist) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->datasist) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\baraa\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->datasist) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\baraa\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->datasist) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\baraa\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\baraa\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\baraa\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\baraa\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (2.32.2)
# Requirement already satisfied: fastjsonschema in c:\users\baraa\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->datasist) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\baraa\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->datasist) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\baraa\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->datasist) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\baraa\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\baraa\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\baraa\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\baraa\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\baraa\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\baraa\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\baraa\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\baraa\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\baraa\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\baraa\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\baraa\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\baraa\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->datasist) (2024.7.4)
# Requirement already satisfied: executing in c:\users\baraa\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\baraa\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->datasist) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\baraa\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->datasist) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\baraa\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist)
#   Downloading webcolors-24.6.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\baraa\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\baraa\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\baraa\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->datasist) (1.2.3)
# Downloading datasist-1.5.3-py3-none-any.whl (33 kB)
# Downloading webcolors-24.6.0-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration, datasist
# Successfully installed datasist-1.5.3 fqdn-1.5.1 isoduration-20.11.0 uri-template-1.3.0 webcolors-24.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasist.structdata import detect_outliers

# %%
outliers_indices = detect_outliers(df, 0, df.columns)
len(outliers_indices)
# Out:
# 238

# %%
df.drop(outliers_indices, inplace=True)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [268 rows x 14 columns]

# %%
sns.boxplot(x='DIS', data=df)
sns.stripplot(x='DIS', data=df, color="#474646")
# Out:
# <Axes: xlabel='DIS'>

# %% [markdown]
# **Outlier Handling via Replacing with Median**

# %%
df = pd.read_csv('boston_house_prices.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
sns.boxplot(x='DIS', data=df)
sns.stripplot(x='DIS', data=df, color="#474646")
# Out:
# <Axes: xlabel='DIS'>

# %%
for col in df.columns:
    outliers_indices = detect_outliers(df, 0, [col])
    col_median = df[col].median()
    df[col].iloc[outliers_indices] = col_median
# Out:
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median
# C:\Users\Baraa\AppData\Local\Temp\ipykernel_14148\293630511.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col].iloc[outliers_indices] = col_median

# %%
sns.boxplot(x='DIS', data=df)
sns.stripplot(x='DIS', data=df, color="#474646")
# Out:
# <Axes: xlabel='DIS'>

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# # Great Work!

# %%
import pandas as pd
df = pd.read_csv('datasets/boston_house_prices.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df["AGE"]
# Out:
# 0      65.2
# 1      78.9
# 2      61.1
# 3      45.8
# 4      54.2
#        ...
# 501    69.1
# 502    76.7
# 503    91.0
# 504    89.3
# 505    80.8
# Name: AGE, Length: 506, dtype: float64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
Q1 = df["MEDV"].quantile(0.25)
Q3 = df["MEDV"].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 7.975000000000001

# %%
lower = Q1 - 1.5 * IQR
upperBonud = Q3 + 1.5 * IQR

# %%
lower
# Out:
# 5.0624999999999964

# %%
upperBonud
# Out:
# 36.962500000000006

# %%
outliers = df[ (df["MEDV"] < lower) | (df["MEDV"] > upperBonud)  ]

outliers
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD  TAX  \
# 97    0.12083   0.0   2.89     0  0.4450  8.069   76.0  3.4952    2  276
# 98    0.08187   0.0   2.89     0  0.4450  7.820   36.9  3.4952    2  276
# 157   1.22358   0.0  19.58     0  0.6050  6.943   97.4  1.8773    5  403
# 161   1.46336   0.0  19.58     0  0.6050  7.489   90.8  1.9709    5  403
# 162   1.83377   0.0  19.58     1  0.6050  7.802   98.2  2.0407    5  403
# 163   1.51902   0.0  19.58     1  0.6050  8.375   93.9  2.1620    5  403
# 166   2.01019   0.0  19.58     0  0.6050  7.929   96.2  2.0459    5  403
# 179   0.05780   0.0   2.46     0  0.4880  6.980   58.4  2.8290    3  193
# 180   0.06588   0.0   2.46     0  0.4880  7.765   83.3  2.7410    3  193
# 182   0.09103   0.0   2.46     0  0.4880  7.155   92.2  2.7006    3  193
# 186   0.05602   0.0   2.46     0  0.4880  7.831   53.6  3.1992    3  193
# 190   0.09068  45.0   3.44     0  0.4370  6.951   21.5  6.4798    5  398
# 195   0.01381  80.0   0.46     0  0.4220  7.875   32.0  5.6484    4  255
# 202   0.02177  82.5   2.03     0  0.4150  7.610   15.7  6.2700    2  348
# 203   0.03510  95.0   2.68     0  0.4161  7.853   33.2  5.1180    4  224
# 204   0.02009  95.0   2.68     0  0.4161  8.034   31.9  5.1180    4  224
# 224   0.31533   0.0   6.20     0  0.5040  8.266   78.3  2.8944    8  307
# 225   0.52693   0.0   6.20     0  0.5040  8.725   83.0  2.8944    8  307
# 226   0.38214   0.0   6.20     0  0.5040  8.040   86.5  3.2157    8  307
# 228   0.29819   0.0   6.20     0  0.5040  7.686   17.0  3.3751    8  307
# 232   0.57529   0.0   6.20     0  0.5070  8.337   73.3  3.8384    8  307
# 233   0.33147   0.0   6.20     0  0.5070  8.247   70.4  3.6519    8  307
# 253   0.36894  22.0   5.86     0  0.4310  8.259    8.4  8.9067    7  330
# 256   0.01538  90.0   3.75     0  0.3940  7.454   34.2  6.3361    3  244
# 257   0.61154  20.0   3.97     0  0.6470  8.704   86.9  1.8010    5  264
# 261   0.53412  20.0   3.97     0  0.6470  7.520   89.4  2.1398    5  264
# 262   0.52014  20.0   3.97     0  0.6470  8.398   91.5  2.2885    5  264
# 267   0.57834  20.0   3.97     0  0.5750  8.297   67.0  2.4216    5  264
# 268   0.54050  20.0   3.97     0  0.5750  7.470   52.6  2.8720    5  264
# 280   0.03578  20.0   3.33     0  0.4429  7.820   64.5  4.6947    5  216
# 282   0.06129  20.0   3.33     1  0.4429  7.645   49.7  5.2119    5  216
# 283   0.01501  90.0   1.21     1  0.4010  7.923   24.8  5.8850    1  198
# 291   0.07886  80.0   4.95     0  0.4110  7.148   27.7  5.1167    4  245
# 368   4.89822   0.0  18.10     0  0.6310  4.970  100.0  1.3325   24  666
# 369   5.66998   0.0  18.10     1  0.6310  6.683   96.8  1.3567   24  666
# 370   6.53876   0.0  18.10     1  0.6310  7.016   97.5  1.2024   24  666
# 371   9.23230   0.0  18.10     0  0.6310  6.216  100.0  1.1691   24  666
# 372   8.26725   0.0  18.10     1  0.6680  5.875   89.6  1.1296   24  666
# 398  38.35180   0.0  18.10     0  0.6930  5.453  100.0  1.4896   24  666
# 405  67.92080   0.0  18.10     0  0.6930  5.683  100.0  1.4254   24  666
#
#      PTRATIO       B  LSTAT  MEDV
# 97      18.0  396.90   4.21  38.7
# 98      18.0  393.53   3.57  43.8
# 157     14.7  363.43   4.59  41.3
# 161     14.7  374.43   1.73  50.0
# 162     14.7  389.61   1.92  50.0
# 163     14.7  388.45   3.32  50.0
# 166     14.7  369.30   3.70  50.0
# 179     17.8  396.90   5.04  37.2
# 180     17.8  395.56   7.56  39.8
# 182     17.8  394.12   4.82  37.9
# 186     17.8  392.63   4.45  50.0
# 190     15.2  377.68   5.10  37.0
# 195     14.4  394.23   2.97  50.0
# 202     14.7  395.38   3.11  42.3
# 203     14.7  392.78   3.81  48.5
# 204     14.7  390.55   2.88  50.0
# 224     17.4  385.05   4.14  44.8
# 225     17.4  382.00   4.63  50.0
# 226     17.4  387.38   3.13  37.6
# 228     17.4  377.51   3.92  46.7
# 232     17.4  385.91   2.47  41.7
# 233     17.4  378.95   3.95  48.3
# 253     19.1  396.90   3.54  42.8
# 256     15.9  386.34   3.11  44.0
# 257     13.0  389.70   5.12  50.0
# 261     13.0  388.37   7.26  43.1
# 262     13.0  386.86   5.91  48.8
# 267     13.0  384.54   7.44  50.0
# 268     13.0  390.30   3.16  43.5
# 280     14.9  387.31   3.76  45.4
# 282     14.9  377.07   3.01  46.0
# 283     13.6  395.52   3.16  50.0
# 291     19.2  396.90   3.56  37.3
# 368     20.2  375.52   3.26  50.0
# 369     20.2  375.33   3.73  50.0
# 370     20.2  392.05   2.96  50.0
# 371     20.2  366.15   9.53  50.0
# 372     20.2  347.88   8.88  50.0
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0
