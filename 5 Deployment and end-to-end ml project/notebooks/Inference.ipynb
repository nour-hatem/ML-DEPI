# %%
import joblib
import pandas as pd

# %%
example_customer = pd.DataFrame({
    "gender": ["Female"],
    "SeniorCitizen": ["Yes"],
    "Partner": ["Yes"],
    "Dependents": ["Yes"],
    "tenure": [1],
    "PhoneService": ["No"],
    "MultipleLines": ["No"],
    "InternetService": ["Fiber optic"],
    "OnlineSecurity": ["No"],
    "OnlineBackup": ["No"],
    "DeviceProtection": ["Yes"],
    "TechSupport": ["No"],
    "StreamingTV": ["Yes"],
    "StreamingMovies": ["Yes"],
    "Contract": ["Two year"],
    "PaperlessBilling": ["Yes"],
    "PaymentMethod": ["Electronic check"],
    "MonthlyCharges": [80.0],
    "TotalCharges": [80.0]
})

# %%
model = joblib.load('log_reg_pipeline.joblib')

# %%
result = model.predict(example_customer)[0]


if result == 1:
  print('Churn')
else:
  print('No Churn')
# Out:
# Churn
